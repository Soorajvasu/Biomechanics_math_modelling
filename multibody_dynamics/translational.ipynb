# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy as sm
import sympy.physics.mechanics as me
me.init_vprinting(use_latex='mathjax')

# %%
alpha, beta = me.dynamicsymbols('alpha beta')
N, A, B = sm.symbols('N A B', cls=me.ReferenceFrame)

A.orient_axis(N, alpha, N.z)
B.orient_axis(A, beta, A.x)

# %%
h, d, w, c, l = sm.symbols('h, d, w, c, l')

r_O_P = h*N.z
r_P_S = -d*A.x
r_S_Q = -w*B.x - (c + l/2)*B.z

r_O_P, r_P_S, r_S_Q
# Out:
# ⎛                        ⎛     l⎞    ⎞
# ⎜h n_z, -d a_x, -w b_x + ⎜-c - ─⎟ b_z⎟
# ⎝                        ⎝     2⎠    ⎠

# %%
(r_O_P + r_P_S).dt(A)
# Out:
# 0

# %%
A.ang_vel_in(N)
# Out:
# α̇ n_z

# %%
me.cross(A.ang_vel_in(N), r_O_P + r_P_S)
# Out:
# -d⋅α̇ a_y

# %%
N_v_S = (r_O_P + r_P_S).dt(A) + me.cross(A.ang_vel_in(N), r_O_P + r_P_S)
N_v_S
# Out:
# -d⋅α̇ a_y

# %%
(r_P_S + r_S_Q).dt(B)
# Out:
# 0

# %%
me.cross(B.ang_vel_in(N), r_P_S + r_S_Q)
# Out:
#            ⎛     l⎞                ⎛              ⎛     l⎞  ⎞                  ↪
# -d⋅α̇ a_y + ⎜-c - ─⎟⋅sin(β)⋅α̇ b_x + ⎜-w⋅cos(β)⋅α̇ - ⎜-c - ─⎟⋅β̇⎟ b_y + w⋅sin(β)⋅α̇ ↪
#            ⎝     2⎠                ⎝              ⎝     2⎠  ⎠                  ↪
#
# ↪
# ↪  b_z
# ↪

# %%
N_v_Q = (r_P_S + r_S_Q).dt(B) + me.cross(B.ang_vel_in(N), r_P_S + r_S_Q)
N_v_Q
# Out:
#            ⎛     l⎞                ⎛              ⎛     l⎞  ⎞                  ↪
# -d⋅α̇ a_y + ⎜-c - ─⎟⋅sin(β)⋅α̇ b_x + ⎜-w⋅cos(β)⋅α̇ - ⎜-c - ─⎟⋅β̇⎟ b_y + w⋅sin(β)⋅α̇ ↪
#            ⎝     2⎠                ⎝              ⎝     2⎠  ⎠                  ↪
#
# ↪
# ↪  b_z
# ↪

# %%
O = me.Point('O')
P = me.Point('P')
S = me.Point('S')
Q = me.Point('Q')

P.set_pos(O, h*N.z)
S.set_pos(P, -d*A.x)
Q.set_pos(S, -w*B.x - (c + l/2)*B.z)

# %%
Q.pos_from(O)
# Out:
#          ⎛     l⎞
# -w b_x + ⎜-c - ─⎟ b_z + -d a_x + h n_z
#          ⎝     2⎠

# %%
O.set_vel(N, 0)

# %%
Q.vel(N)
# Out:
# ⎛     l⎞                ⎛              ⎛     l⎞  ⎞                             ↪
# ⎜-c - ─⎟⋅sin(β)⋅α̇ b_x + ⎜-w⋅cos(β)⋅α̇ - ⎜-c - ─⎟⋅β̇⎟ b_y + w⋅sin(β)⋅α̇ b_z + -d⋅α̇ ↪
# ⎝     2⎠                ⎝              ⎝     2⎠  ⎠                             ↪
#
# ↪
# ↪  a_y
# ↪

# %%
Bc = me.Point('B_c')
Bc.set_pos(S, -c*B.z - w/2*A.x)
me.cross(B.ang_vel_in(A), Bc.pos_from(S))
# Out:
# c⋅β̇ b_y

# %%
N_v_P = 0*N.z

# %%
N_v_S = N_v_P +  me.cross(A.ang_vel_in(N), S.pos_from(P))
N_v_S
# Out:
# -d⋅α̇ a_y

# %%
P.set_vel(N, 0)
S.v2pt_theory(P, N, A)
# Out:
# -d⋅α̇ a_y

# %%
S.vel(N)
# Out:
# -d⋅α̇ a_y

# %%
N_v_Q = N_v_S +  me.cross(B.ang_vel_in(N), Q.pos_from(S))
N_v_Q
# Out:
#            ⎛     l⎞                ⎛              ⎛     l⎞  ⎞                  ↪
# -d⋅α̇ a_y + ⎜-c - ─⎟⋅sin(β)⋅α̇ b_x + ⎜-w⋅cos(β)⋅α̇ - ⎜-c - ─⎟⋅β̇⎟ b_y + w⋅sin(β)⋅α̇ ↪
#            ⎝     2⎠                ⎝              ⎝     2⎠  ⎠                  ↪
#
# ↪
# ↪  b_z
# ↪

# %%
Q.v2pt_theory(S, N, B)
# Out:
#            ⎛     l⎞                ⎛              ⎛     l⎞  ⎞                  ↪
# -d⋅α̇ a_y + ⎜-c - ─⎟⋅sin(β)⋅α̇ b_x + ⎜-w⋅cos(β)⋅α̇ - ⎜-c - ─⎟⋅β̇⎟ b_y + w⋅sin(β)⋅α̇ ↪
#            ⎝     2⎠                ⎝              ⎝     2⎠  ⎠                  ↪
#
# ↪
# ↪  b_z
# ↪

# %%
Bc = me.Point('B_c')
Bc.set_pos(S, -c*B.z - w/2*A.x)
Bc.v2pt_theory(S, N, B)
# Out:
# ⎛       w⋅α̇⎞
# ⎜-d⋅α̇ - ───⎟ a_y + -c⋅sin(β)⋅α̇ b_x + c⋅β̇ b_y
# ⎝        2 ⎠

# %%
s = me.dynamicsymbols('s')
t = me.dynamicsymbols._t

R = me.Point('R')
R.set_pos(Q, l*B.z + s*B.x)

# %%
B_v_R = s.diff(t)*B.x
B_v_R
# Out:
# ṡ b_x

# %%
r_S_R = R.pos_from(S)
r_S_R
# Out:
#                ⎛     l⎞
# (-w + s) b_x + ⎜-c + ─⎟ b_z
#                ⎝     2⎠

# %%
N_v_T = N_v_S + me.cross(B.ang_vel_in(N), r_S_R)
N_v_T
# Out:
#            ⎛     l⎞                ⎛  ⎛     l⎞                      ⎞          ↪
# -d⋅α̇ a_y + ⎜-c + ─⎟⋅sin(β)⋅α̇ b_x + ⎜- ⎜-c + ─⎟⋅β̇ + (-w + s)⋅cos(β)⋅α̇⎟ b_y + -( ↪
#            ⎝     2⎠                ⎝  ⎝     2⎠                      ⎠          ↪
#
# ↪
# ↪ -w + s)⋅sin(β)⋅α̇ b_z
# ↪

# %%
N_v_R = B_v_R + N_v_T
N_v_R
# Out:
# ⎛⎛     l⎞             ⎞       ⎛  ⎛     l⎞                      ⎞               ↪
# ⎜⎜-c + ─⎟⋅sin(β)⋅α̇ + ṡ⎟ b_x + ⎜- ⎜-c + ─⎟⋅β̇ + (-w + s)⋅cos(β)⋅α̇⎟ b_y + -(-w +  ↪
# ⎝⎝     2⎠             ⎠       ⎝  ⎝     2⎠                      ⎠               ↪
#
# ↪
# ↪ s)⋅sin(β)⋅α̇ b_z + -d⋅α̇ a_y
# ↪

# %%
S.set_vel(B, 0)
R.v1pt_theory(S, N, B)
# Out:
# ⎛⎛     l⎞             ⎞       ⎛  ⎛     l⎞                      ⎞               ↪
# ⎜⎜-c + ─⎟⋅sin(β)⋅α̇ + ṡ⎟ b_x + ⎜- ⎜-c + ─⎟⋅β̇ + (-w + s)⋅cos(β)⋅α̇⎟ b_y + -(-w +  ↪
# ⎝⎝     2⎠             ⎠       ⎝  ⎝     2⎠                      ⎠               ↪
#
# ↪
# ↪ s)⋅sin(β)⋅α̇ b_z + -d⋅α̇ a_y
# ↪

# %%
S.acc(N)
# Out:
#    2
# d⋅α̇  a_x + -d⋅α̈ a_y

# %%
me.cross(A.ang_acc_in(N), S.pos_from(P))
# Out:
# -d⋅α̈ a_y

# %%
me.cross(A.ang_vel_in(N), me.cross(A.ang_vel_in(N), S.pos_from(P)))
# Out:
#    2
# d⋅α̇  a_x

# %%
S.a2pt_theory(P, N, A)
# Out:
#    2
# d⋅α̇  a_x + -d⋅α̈ a_y

# %%
Q.a2pt_theory(S, N, B)
# Out:
#    2                  ⎛     2     2   ⎛     l⎞                           ⎛     ↪
# d⋅α̇  a_x + -d⋅α̈ a_y + ⎜w⋅sin (β)⋅α̇  + ⎜-c - ─⎟⋅(sin(β)⋅α̈ + cos(β)⋅α̇⋅β̇) - ⎜-w⋅c ↪
#                       ⎝               ⎝     2⎠                           ⎝     ↪
#
# ↪           ⎛     l⎞  ⎞         ⎞       ⎛                                      ↪
# ↪ os(β)⋅α̇ - ⎜-c - ─⎟⋅β̇⎟⋅cos(β)⋅α̇⎟ b_x + ⎜-w⋅(-sin(β)⋅α̇⋅β̇ + cos(β)⋅α̈) - w⋅sin(β ↪
# ↪           ⎝     2⎠  ⎠         ⎠       ⎝                                      ↪
#
# ↪         ⎛     l⎞                2   ⎛     l⎞  ⎞       ⎛                      ↪
# ↪ )⋅α̇⋅β̇ + ⎜-c - ─⎟⋅sin(β)⋅cos(β)⋅α̇  - ⎜-c - ─⎟⋅β̈⎟ b_y + ⎜w⋅(sin(β)⋅α̈ + cos(β)⋅ ↪
# ↪         ⎝     2⎠                    ⎝     2⎠  ⎠       ⎝                      ↪
#
# ↪        ⎛     l⎞    2     2   ⎛              ⎛     l⎞  ⎞  ⎞
# ↪ α̇⋅β̇) - ⎜-c - ─⎟⋅sin (β)⋅α̇  + ⎜-w⋅cos(β)⋅α̇ - ⎜-c - ─⎟⋅β̇⎟⋅β̇⎟ b_z
# ↪        ⎝     2⎠              ⎝              ⎝     2⎠  ⎠  ⎠

# %%
B_a_R = R.acc(B)
B_a_R
# Out:
# s̈ b_x

# %%
N_a_T = R.a2pt_theory(S, N, B)
N_a_T
# Out:
#    2                  ⎛⎛     l⎞                                       2     2  ↪
# d⋅α̇  a_x + -d⋅α̈ a_y + ⎜⎜-c + ─⎟⋅(sin(β)⋅α̈ + cos(β)⋅α̇⋅β̇) - (-w + s)⋅sin (β)⋅α̇   ↪
#                       ⎝⎝     2⎠                                                ↪
#
# ↪   ⎛  ⎛     l⎞                      ⎞         ⎞       ⎛⎛     l⎞               ↪
# ↪ - ⎜- ⎜-c + ─⎟⋅β̇ + (-w + s)⋅cos(β)⋅α̇⎟⋅cos(β)⋅α̇⎟ b_x + ⎜⎜-c + ─⎟⋅sin(β)⋅cos(β) ↪
# ↪   ⎝  ⎝     2⎠                      ⎠         ⎠       ⎝⎝     2⎠               ↪
#
# ↪   2   ⎛     l⎞                                                            ⎞  ↪
# ↪ ⋅α̇  - ⎜-c + ─⎟⋅β̈ + (-w + s)⋅(-sin(β)⋅α̇⋅β̇ + cos(β)⋅α̈) + (-w + s)⋅sin(β)⋅α̇⋅β̇⎟  ↪
# ↪       ⎝     2⎠                                                            ⎠  ↪
#
# ↪       ⎛  ⎛     l⎞    2     2                                      ⎛  ⎛     l ↪
# ↪ b_y + ⎜- ⎜-c + ─⎟⋅sin (β)⋅α̇  - (-w + s)⋅(sin(β)⋅α̈ + cos(β)⋅α̇⋅β̇) + ⎜- ⎜-c + ─ ↪
# ↪       ⎝  ⎝     2⎠                                                 ⎝  ⎝     2 ↪
#
# ↪ ⎞                      ⎞  ⎞
# ↪ ⎟⋅β̇ + (-w + s)⋅cos(β)⋅α̇⎟⋅β̇⎟ b_z
# ↪ ⎠                      ⎠  ⎠

# %%
2*me.cross(B.ang_vel_in(N), R.vel(B))
# Out:
# 2⋅cos(β)⋅α̇⋅ṡ b_y + -2⋅sin(β)⋅α̇⋅ṡ b_z

# %%
R.a1pt_theory(S, N, B)
# Out:
# ⎛⎛     l⎞                                       2     2   ⎛  ⎛     l⎞          ↪
# ⎜⎜-c + ─⎟⋅(sin(β)⋅α̈ + cos(β)⋅α̇⋅β̇) - (-w + s)⋅sin (β)⋅α̇  - ⎜- ⎜-c + ─⎟⋅β̇ + (-w  ↪
# ⎝⎝     2⎠                                                 ⎝  ⎝     2⎠          ↪
#
# ↪              ⎞             ⎞       ⎛⎛     l⎞                2   ⎛     l⎞     ↪
# ↪ + s)⋅cos(β)⋅α̇⎟⋅cos(β)⋅α̇ + s̈⎟ b_x + ⎜⎜-c + ─⎟⋅sin(β)⋅cos(β)⋅α̇  - ⎜-c + ─⎟⋅β̈ + ↪
# ↪              ⎠             ⎠       ⎝⎝     2⎠                    ⎝     2⎠     ↪
#
# ↪                                                                        ⎞     ↪
# ↪  (-w + s)⋅(-sin(β)⋅α̇⋅β̇ + cos(β)⋅α̈) + (-w + s)⋅sin(β)⋅α̇⋅β̇ + 2⋅cos(β)⋅α̇⋅ṡ⎟ b_y ↪
# ↪                                                                        ⎠     ↪
#
# ↪    ⎛  ⎛     l⎞    2     2                                      ⎛  ⎛     l⎞   ↪
# ↪  + ⎜- ⎜-c + ─⎟⋅sin (β)⋅α̇  - (-w + s)⋅(sin(β)⋅α̈ + cos(β)⋅α̇⋅β̇) + ⎜- ⎜-c + ─⎟⋅β̇ ↪
# ↪    ⎝  ⎝     2⎠                                                 ⎝  ⎝     2⎠   ↪
#
# ↪                     ⎞                 ⎞          2
# ↪  + (-w + s)⋅cos(β)⋅α̇⎟⋅β̇ - 2⋅sin(β)⋅α̇⋅ṡ⎟ b_z + d⋅α̇  a_x + -d⋅α̈ a_y
# ↪                     ⎠                 ⎠

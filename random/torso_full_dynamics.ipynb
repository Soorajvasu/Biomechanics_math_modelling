# %%
import sympy as sp
import sympy.physics.mechanics as me 
sp.init_printing(use_latex="mathjax")
me.init_vprinting()
from IPython.display import display

# %%
# Frames, points, coordinates declaration

N, B, U1, U2, L1, L2 = sp.symbols('N, B, U_1, U_2, L_1, L_2', cls=me.ReferenceFrame)
O, T, C1, C2, R1, R2 = sp.symbols('O, T, C_1, C_2, R_1, R_2', cls=me.Point)                                 # CoM points for the bodies
A1, A2, B1, B2, K1, K2, O1, O2 = sp.symbols('A_1, A_2, B_1, B_2, K_1, K_2, O_1, O_2', cls=me.Point)         # points for constraints / loop closure
alpha, beta = me.dynamicsymbols('alpha beta', real="True")
theta1, theta2 = me.dynamicsymbols('theta1:3', real="True")
psi1, psi2, psi3, psi4, psi5, psi6 = me.dynamicsymbols('psi1:7', real="True")
lt, ls, lc, lr, lf = sp.symbols('l_t, l_s, l_c, l_r, l_f' , positive="True", real="True")
m, g = sp.symbols('m, g', real="True", positive="True")
t = me.dynamicsymbols._t


p = sp.Matrix([ lt, ls, lc, lr, lf, m, g])
u1, u2, u3, u4, u5, u6, u7, u8, u9, u10 = me.dynamicsymbols('u1:11')
q = sp.Matrix([theta1, theta2])
qr = sp.Matrix([alpha, beta, psi1, psi2, psi3, psi4, psi5, psi6])
qN = q.col_join(qr)

u = sp.Matrix([u1, u2])
ur = sp.Matrix([u3, u4, u5, u6, u7, u8, u9, u10])
uN = u.col_join(ur)

qdN = qN.diff(t)
ud = u.diff(t)

qn_zero = {q:0 for q in qN}
ur_zero = {u: 0 for u in ur}
uN_zero = {u: 0 for u in uN}
qdN_zero = {qd: 0 for qd in qdN}
ud_zero = {ud: 0 for ud in ud}

q, qr, qN, u, ur, uN, qdN, ud
# Out:
# ⎛            ⎡θ₁⎤               ⎡u₁ ⎤  ⎡θ₁̇⎤      ⎞
# ⎜            ⎢  ⎥               ⎢   ⎥  ⎢  ⎥      ⎟
# ⎜      ⎡α ⎤  ⎢θ₂⎥        ⎡u₃ ⎤  ⎢u₂ ⎥  ⎢θ₂̇⎥      ⎟
# ⎜      ⎢  ⎥  ⎢  ⎥        ⎢   ⎥  ⎢   ⎥  ⎢  ⎥      ⎟
# ⎜      ⎢β ⎥  ⎢α ⎥        ⎢u₄ ⎥  ⎢u₃ ⎥  ⎢α̇ ⎥      ⎟
# ⎜      ⎢  ⎥  ⎢  ⎥        ⎢   ⎥  ⎢   ⎥  ⎢  ⎥      ⎟
# ⎜      ⎢ψ₁⎥  ⎢β ⎥        ⎢u₅ ⎥  ⎢u₄ ⎥  ⎢β̇ ⎥      ⎟
# ⎜      ⎢  ⎥  ⎢  ⎥        ⎢   ⎥  ⎢   ⎥  ⎢  ⎥      ⎟
# ⎜⎡θ₁⎤  ⎢ψ₂⎥  ⎢ψ₁⎥  ⎡u₁⎤  ⎢u₆ ⎥  ⎢u₅ ⎥  ⎢ψ₁̇⎥  ⎡u₁̇⎤⎟
# ⎜⎢  ⎥, ⎢  ⎥, ⎢  ⎥, ⎢  ⎥, ⎢   ⎥, ⎢   ⎥, ⎢  ⎥, ⎢  ⎥⎟
# ⎜⎣θ₂⎦  ⎢ψ₃⎥  ⎢ψ₂⎥  ⎣u₂⎦  ⎢u₇ ⎥  ⎢u₆ ⎥  ⎢ψ₂̇⎥  ⎣u₂̇⎦⎟
# ⎜      ⎢  ⎥  ⎢  ⎥        ⎢   ⎥  ⎢   ⎥  ⎢  ⎥      ⎟
# ⎜      ⎢ψ₄⎥  ⎢ψ₃⎥        ⎢u₈ ⎥  ⎢u₇ ⎥  ⎢ψ₃̇⎥      ⎟
# ⎜      ⎢  ⎥  ⎢  ⎥        ⎢   ⎥  ⎢   ⎥  ⎢  ⎥      ⎟
# ⎜      ⎢ψ₅⎥  ⎢ψ₄⎥        ⎢u₉ ⎥  ⎢u₈ ⎥  ⎢ψ₄̇⎥      ⎟
# ⎜      ⎢  ⎥  ⎢  ⎥        ⎢   ⎥  ⎢   ⎥  ⎢  ⎥      ⎟
# ⎜      ⎣ψ₆⎦  ⎢ψ₅⎥        ⎣u₁₀⎦  ⎢u₉ ⎥  ⎢ψ₅̇⎥      ⎟
# ⎜            ⎢  ⎥               ⎢   ⎥  ⎢  ⎥      ⎟
# ⎝            ⎣ψ₆⎦               ⎣u₁₀⎦  ⎣ψ₆̇⎦      ⎠

# %%
# Framing and coordinates setting

B.orient_body_fixed(N, (alpha, beta, 0), 'XYZ')
U1.orient_axis(B, B.y, theta1)
L1.orient_body_fixed(U1, (psi1, psi2, psi3), 'XYZ')

U2.orient_axis(B, B.y, theta2)
L2.orient_body_fixed(U2, (psi4, psi5, psi6), 'XYZ')

O1.set_pos(O, lc*N.x + ls/2*N.y - lf*N.z)
O2.set_pos(O, lc*N.x - ls/2*N.y - lf*N.z)
T.set_pos(O, lt*B.z)

A1.set_pos(O, ls/2*U1.y + (lr-lf)*U1.z)
C1.set_pos(O, lc/2*U1.x + ls/2*U1.y + (lr-lf)*U1.z)
B1.set_pos(C1, lc/2*L1.x)
R1.set_pos(B1,- lr/2*L1.z)
K1.set_pos(R1,- lr/2*L1.z)


A2.set_pos(O,- ls/2*U2.y + (lr-lf)*U2.z)
C2.set_pos(O, lc/2*U2.x - ls/2*U2.y + (lr-lf)*U2.z)
B2.set_pos(C2, lc/2*L2.x)
R2.set_pos(B2,- lr/2*L2.z)
K2.set_pos(R2,- lr/2*L2.z)

# %%
# position check

K1.pos_from(O).express(N).xreplace(qn_zero)
# Out:
#           lₛ
# l_c n_x + ── n_y + -l_f n_z
#           2

# %%
me.find_dynamicsymbols(T.pos_from(O), reference_frame=N), me.find_dynamicsymbols(C1.pos_from(O), reference_frame=N), me.find_dynamicsymbols(C2.pos_from(O), reference_frame=N), me.find_dynamicsymbols(R1.pos_from(O), reference_frame=N),me.find_dynamicsymbols(K1.pos_from(O), reference_frame=N), me.find_dynamicsymbols(R2.pos_from(O), reference_frame=N),  me.find_dynamicsymbols(K2.pos_from(O), reference_frame=N)
# Out:
# ({α, β}, {α, β, θ₁}, {α, β, θ₂}, {α, β, ψ₁, ψ₂, ψ₃, θ₁}, {α, β, ψ₁, ψ₂, ψ₃, θ₁ ↪
#
# ↪ }, {α, β, ψ₄, ψ₅, ψ₆, θ₂}, {α, β, ψ₄, ψ₅, ψ₆, θ₂})

# %% [markdown]
# ## Holonomic constraints

# %%
# loop closure equations

loop_closure1 = K1.pos_from(O) - (lc*N.x + ls/2*N.y)
loop_closure2 = K2.pos_from(O) - (lc*N.x - ls/2*N.y)

constraints = [
    loop_closure1,
    loop_closure2,
    ]

for c in constraints:
    display(c.express(N))
# Out:
# ⎛l_c⋅(-sin(β)⋅sin(θ₁) + cos(β)⋅cos(θ₁))   l_c⋅((-sin(β)⋅sin(θ₁) + cos(β)⋅cos(θ ↪
# ⎜────────────────────────────────────── + ──────────────────────────────────── ↪
# ⎝                  2                                                           ↪
#
# ↪ ₁))⋅cos(ψ₂)⋅cos(ψ₃) + (sin(β)⋅cos(θ₁) + sin(θ₁)⋅cos(β))⋅(sin(ψ₁)⋅sin(ψ₃) - s ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                2                                             ↪
#
# ↪ in(ψ₂)⋅cos(ψ₁)⋅cos(ψ₃)))                                                     ↪
# ↪ ──────────────────────── - l_c - lᵣ⋅((-sin(β)⋅sin(θ₁) + cos(β)⋅cos(θ₁))⋅sin( ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ ψ₂) + (sin(β)⋅cos(θ₁) + sin(θ₁)⋅cos(β))⋅cos(ψ₁)⋅cos(ψ₂)) + (-l_f + lᵣ)⋅(sin( ↪
# ↪                                                                              ↪
#
# ↪                             ⎞       ⎛l_c⋅(sin(α)⋅sin(β)⋅cos(θ₁) + sin(α)⋅sin ↪
# ↪ β)⋅cos(θ₁) + sin(θ₁)⋅cos(β))⎟ n_x + ⎜─────────────────────────────────────── ↪
# ↪                             ⎠       ⎝                         2              ↪
#
# ↪ (θ₁)⋅cos(β))   l_c⋅((sin(ψ₁)⋅sin(ψ₃) - sin(ψ₂)⋅cos(ψ₁)⋅cos(ψ₃))⋅(sin(α)⋅sin( ↪
# ↪ ──────────── + ───────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪ β)⋅sin(θ₁) - sin(α)⋅cos(β)⋅cos(θ₁)) + (sin(α)⋅sin(β)⋅cos(θ₁) + sin(α)⋅sin(θ₁ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                               2                              ↪
#
# ↪ )⋅cos(β))⋅cos(ψ₂)⋅cos(ψ₃) + (sin(ψ₁)⋅sin(ψ₂)⋅cos(ψ₃) + sin(ψ₃)⋅cos(ψ₁))⋅cos( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪ α))                                                                          ↪
# ↪ ─── - lᵣ⋅((sin(α)⋅sin(β)⋅sin(θ₁) - sin(α)⋅cos(β)⋅cos(θ₁))⋅cos(ψ₁)⋅cos(ψ₂) +  ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ (sin(α)⋅sin(β)⋅cos(θ₁) + sin(α)⋅sin(θ₁)⋅cos(β))⋅sin(ψ₂) - sin(ψ₁)⋅cos(α)⋅cos ↪
# ↪                                                                              ↪
#
# ↪         lₛ⋅cos(α)   lₛ                                                       ↪
# ↪ (ψ₂)) + ───────── - ── + (-l_f + lᵣ)⋅(sin(α)⋅sin(β)⋅sin(θ₁) - sin(α)⋅cos(β)⋅ ↪
# ↪             2       2                                                        ↪
#
# ↪         ⎞       ⎛l_c⋅(-sin(β)⋅cos(α)⋅cos(θ₁) - sin(θ₁)⋅cos(α)⋅cos(β))   l_c⋅ ↪
# ↪ cos(θ₁))⎟ n_y + ⎜──────────────────────────────────────────────────── + ──── ↪
# ↪         ⎠       ⎝                         2                                  ↪
#
# ↪ ((sin(ψ₁)⋅sin(ψ₃) - sin(ψ₂)⋅cos(ψ₁)⋅cos(ψ₃))⋅(-sin(β)⋅sin(θ₁)⋅cos(α) + cos(α ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪ )⋅cos(β)⋅cos(θ₁)) + (-sin(β)⋅cos(α)⋅cos(θ₁) - sin(θ₁)⋅cos(α)⋅cos(β))⋅cos(ψ₂) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                             2                                                ↪
#
# ↪ ⋅cos(ψ₃) + (sin(ψ₁)⋅sin(ψ₂)⋅cos(ψ₃) + sin(ψ₃)⋅cos(ψ₁))⋅sin(α))               ↪
# ↪ ────────────────────────────────────────────────────────────── - lᵣ⋅((-sin(β ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ )⋅sin(θ₁)⋅cos(α) + cos(α)⋅cos(β)⋅cos(θ₁))⋅cos(ψ₁)⋅cos(ψ₂) + (-sin(β)⋅cos(α)⋅ ↪
# ↪                                                                              ↪
#
# ↪                                                                      lₛ⋅sin( ↪
# ↪ cos(θ₁) - sin(θ₁)⋅cos(α)⋅cos(β))⋅sin(ψ₂) - sin(α)⋅sin(ψ₁)⋅cos(ψ₂)) + ─────── ↪
# ↪                                                                          2   ↪
#
# ↪ α)                                                               ⎞
# ↪ ── + (-l_f + lᵣ)⋅(-sin(β)⋅sin(θ₁)⋅cos(α) + cos(α)⋅cos(β)⋅cos(θ₁))⎟ n_z
# ↪                                                                  ⎠
# ⎛l_c⋅(-sin(β)⋅sin(θ₂) + cos(β)⋅cos(θ₂))   l_c⋅((-sin(β)⋅sin(θ₂) + cos(β)⋅cos(θ ↪
# ⎜────────────────────────────────────── + ──────────────────────────────────── ↪
# ⎝                  2                                                           ↪
#
# ↪ ₂))⋅cos(ψ₅)⋅cos(ψ₆) + (sin(β)⋅cos(θ₂) + sin(θ₂)⋅cos(β))⋅(sin(ψ₄)⋅sin(ψ₆) - s ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                2                                             ↪
#
# ↪ in(ψ₅)⋅cos(ψ₄)⋅cos(ψ₆)))                                                     ↪
# ↪ ──────────────────────── - l_c - lᵣ⋅((-sin(β)⋅sin(θ₂) + cos(β)⋅cos(θ₂))⋅sin( ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ ψ₅) + (sin(β)⋅cos(θ₂) + sin(θ₂)⋅cos(β))⋅cos(ψ₄)⋅cos(ψ₅)) + (-l_f + lᵣ)⋅(sin( ↪
# ↪                                                                              ↪
#
# ↪                             ⎞       ⎛l_c⋅(sin(α)⋅sin(β)⋅cos(θ₂) + sin(α)⋅sin ↪
# ↪ β)⋅cos(θ₂) + sin(θ₂)⋅cos(β))⎟ n_x + ⎜─────────────────────────────────────── ↪
# ↪                             ⎠       ⎝                         2              ↪
#
# ↪ (θ₂)⋅cos(β))   l_c⋅((sin(ψ₄)⋅sin(ψ₆) - sin(ψ₅)⋅cos(ψ₄)⋅cos(ψ₆))⋅(sin(α)⋅sin( ↪
# ↪ ──────────── + ───────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪ β)⋅sin(θ₂) - sin(α)⋅cos(β)⋅cos(θ₂)) + (sin(α)⋅sin(β)⋅cos(θ₂) + sin(α)⋅sin(θ₂ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                               2                              ↪
#
# ↪ )⋅cos(β))⋅cos(ψ₅)⋅cos(ψ₆) + (sin(ψ₄)⋅sin(ψ₅)⋅cos(ψ₆) + sin(ψ₆)⋅cos(ψ₄))⋅cos( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪ α))                                                                          ↪
# ↪ ─── - lᵣ⋅((sin(α)⋅sin(β)⋅sin(θ₂) - sin(α)⋅cos(β)⋅cos(θ₂))⋅cos(ψ₄)⋅cos(ψ₅) +  ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ (sin(α)⋅sin(β)⋅cos(θ₂) + sin(α)⋅sin(θ₂)⋅cos(β))⋅sin(ψ₅) - sin(ψ₄)⋅cos(α)⋅cos ↪
# ↪                                                                              ↪
#
# ↪         lₛ⋅cos(α)   lₛ                                                       ↪
# ↪ (ψ₅)) - ───────── + ── + (-l_f + lᵣ)⋅(sin(α)⋅sin(β)⋅sin(θ₂) - sin(α)⋅cos(β)⋅ ↪
# ↪             2       2                                                        ↪
#
# ↪         ⎞       ⎛l_c⋅(-sin(β)⋅cos(α)⋅cos(θ₂) - sin(θ₂)⋅cos(α)⋅cos(β))   l_c⋅ ↪
# ↪ cos(θ₂))⎟ n_y + ⎜──────────────────────────────────────────────────── + ──── ↪
# ↪         ⎠       ⎝                         2                                  ↪
#
# ↪ ((sin(ψ₄)⋅sin(ψ₆) - sin(ψ₅)⋅cos(ψ₄)⋅cos(ψ₆))⋅(-sin(β)⋅sin(θ₂)⋅cos(α) + cos(α ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
#
# ↪ )⋅cos(β)⋅cos(θ₂)) + (-sin(β)⋅cos(α)⋅cos(θ₂) - sin(θ₂)⋅cos(α)⋅cos(β))⋅cos(ψ₅) ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                             2                                                ↪
#
# ↪ ⋅cos(ψ₆) + (sin(ψ₄)⋅sin(ψ₅)⋅cos(ψ₆) + sin(ψ₆)⋅cos(ψ₄))⋅sin(α))               ↪
# ↪ ────────────────────────────────────────────────────────────── - lᵣ⋅((-sin(β ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪ )⋅sin(θ₂)⋅cos(α) + cos(α)⋅cos(β)⋅cos(θ₂))⋅cos(ψ₄)⋅cos(ψ₅) + (-sin(β)⋅cos(α)⋅ ↪
# ↪                                                                              ↪
#
# ↪                                                                      lₛ⋅sin( ↪
# ↪ cos(θ₂) - sin(θ₂)⋅cos(α)⋅cos(β))⋅sin(ψ₅) - sin(α)⋅sin(ψ₄)⋅cos(ψ₅)) - ─────── ↪
# ↪                                                                          2   ↪
#
# ↪ α)                                                               ⎞
# ↪ ── + (-l_f + lᵣ)⋅(-sin(β)⋅sin(θ₂)⋅cos(α) + cos(α)⋅cos(β)⋅cos(θ₂))⎟ n_z
# ↪                                                                  ⎠

# %%
# Holonomic constraints

fh = sp.Matrix([sp.trigsimp(loop_closure1.dot(N.x)),
                sp.trigsimp(loop_closure1.dot(N.y)),
                sp.trigsimp(loop_closure2.dot(N.x)),
                sp.trigsimp(loop_closure2.dot(N.y))
                ])

fh.simplify()

# %%
fh
# Out:
# ⎡                                                                  l_c⋅((sin(ψ ↪
# ⎢                                                                  ─────────── ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢l_c⋅(-(sin(ψ₁)⋅sin(ψ₃) - sin(ψ₂)⋅cos(ψ₁)⋅cos(ψ₃))⋅sin(α)⋅cos(β + θ₁) + (sin(ψ ↪
# ⎢───────────────────────────────────────────────────────────────────────────── ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                  l_c⋅((sin(ψ ↪
# ⎢                                                                  ─────────── ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢l_c⋅(-(sin(ψ₄)⋅sin(ψ₆) - sin(ψ₅)⋅cos(ψ₄)⋅cos(ψ₆))⋅sin(α)⋅cos(β + θ₂) + (sin(ψ ↪
# ⎢───────────────────────────────────────────────────────────────────────────── ↪
# ⎣                                                                              ↪
#
# ↪ ₁)⋅sin(ψ₃) - sin(ψ₂)⋅cos(ψ₁)⋅cos(ψ₃))⋅sin(β + θ₁) + cos(β + θ₁)⋅cos(ψ₂)⋅cos( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                   2                                          ↪
# ↪                                                                              ↪
# ↪ ₁)⋅sin(ψ₂)⋅cos(ψ₃) + sin(ψ₃)⋅cos(ψ₁))⋅cos(α) + sin(β + θ₁)⋅sin(α)⋅cos(ψ₂)⋅co ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪   2                                                                          ↪
# ↪                                                                              ↪
# ↪ ₄)⋅sin(ψ₆) - sin(ψ₅)⋅cos(ψ₄)⋅cos(ψ₆))⋅sin(β + θ₂) + cos(β + θ₂)⋅cos(ψ₅)⋅cos( ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                   2                                          ↪
# ↪                                                                              ↪
# ↪ ₄)⋅sin(ψ₅)⋅cos(ψ₆) + sin(ψ₆)⋅cos(ψ₄))⋅cos(α) + sin(β + θ₂)⋅sin(α)⋅cos(ψ₅)⋅co ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪   2                                                                          ↪
#
# ↪ ψ₃))   l_c⋅cos(β + θ₁)                                                       ↪
# ↪ ──── + ─────────────── - l_c - lᵣ⋅(sin(β + θ₁)⋅cos(ψ₁)⋅cos(ψ₂) + sin(ψ₂)⋅cos ↪
# ↪               2                                                              ↪
# ↪                                                                              ↪
# ↪ s(ψ₃))   l_c⋅sin(β + θ₁)⋅sin(α)                                              ↪
# ↪ ────── + ────────────────────── + lᵣ⋅(-sin(β + θ₁)⋅sin(α)⋅sin(ψ₂) + sin(α)⋅c ↪
# ↪                    2                                                         ↪
# ↪                                                                              ↪
# ↪ ψ₆))   l_c⋅cos(β + θ₂)                                                       ↪
# ↪ ──── + ─────────────── - l_c - lᵣ⋅(sin(β + θ₂)⋅cos(ψ₄)⋅cos(ψ₅) + sin(ψ₅)⋅cos ↪
# ↪               2                                                              ↪
# ↪                                                                              ↪
# ↪ s(ψ₆))   l_c⋅sin(β + θ₂)⋅sin(α)                                              ↪
# ↪ ────── + ────────────────────── + lᵣ⋅(-sin(β + θ₂)⋅sin(α)⋅sin(ψ₅) + sin(α)⋅c ↪
# ↪                    2                                                         ↪
#
# ↪                                                                              ↪
# ↪ (β + θ₁)) + (-l_f + lᵣ)⋅sin(β + θ₁)                                          ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                        lₛ⋅cos(α)   lₛ        ↪
# ↪ os(β + θ₁)⋅cos(ψ₁)⋅cos(ψ₂) + sin(ψ₁)⋅cos(α)⋅cos(ψ₂)) + ───────── - ── + (l_f ↪
# ↪                                                            2       2         ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ (β + θ₂)) + (-l_f + lᵣ)⋅sin(β + θ₂)                                          ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                        lₛ⋅cos(α)   lₛ        ↪
# ↪ os(β + θ₂)⋅cos(ψ₄)⋅cos(ψ₅) + sin(ψ₄)⋅cos(α)⋅cos(ψ₅)) - ───────── + ── + (l_f ↪
# ↪                                                            2       2         ↪
#
# ↪                          ⎤
# ↪                          ⎥
# ↪                          ⎥
# ↪                          ⎥
# ↪                          ⎥
# ↪  - lᵣ)⋅sin(α)⋅cos(β + θ₁)⎥
# ↪                          ⎥
# ↪                          ⎥
# ↪                          ⎥
# ↪                          ⎥
# ↪                          ⎥
# ↪                          ⎥
# ↪                          ⎥
# ↪  - lᵣ)⋅sin(α)⋅cos(β + θ₂)⎥
# ↪                          ⎦

# %%
me.find_dynamicsymbols(fh[0]), me.find_dynamicsymbols(fh[1]), me.find_dynamicsymbols(fh[2]), me.find_dynamicsymbols(fh[3])
# Out:
# ({β, ψ₁, ψ₂, ψ₃, θ₁}, {α, β, ψ₁, ψ₂, ψ₃, θ₁}, {β, ψ₄, ψ₅, ψ₆, θ₂}, {α, β, ψ₄,  ↪
#
# ↪ ψ₅, ψ₆, θ₂})
